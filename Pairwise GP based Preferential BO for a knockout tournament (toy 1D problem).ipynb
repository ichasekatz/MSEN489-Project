# %%
#%pip install torch gpytorch botorch

import torch
import numpy as np
import matplotlib.pyplot as plt
from botorch.fit import fit_gpytorch_mll
from botorch.models.pairwise_gp import PairwiseGP, PairwiseLaplaceMarginalLogLikelihood
from botorch.models.transforms.input import Normalize
from botorch.acquisition.preference import AnalyticExpectedUtilityOfBestOption
from botorch.optim import optimize_acqf
from scipy.stats import kendalltau

teams = [
    "Bangladesh", "India", "Pakistan", "Nepal", "Afghanistan",
    "Sri Lanka", "USA", "South Africa", "England", "West Indies",
    "Zimbabwe", "Ireland", "Netherlands", "Canada", "Australia", "Kenya", "Argentina"
]

n_teams = len(teams)

comp_matrix = np.full((n_teams, n_teams), np.nan)

print("Teams:")
for idx, team in enumerate(teams):
    print(f"{idx+1}: {team}")

def query_user_for_comparison(i, j):
    """Query the user for comparison between two teams"""
    user_input = input(f"Which team is preferred between {teams[i]} vs {teams[j]}? (1 for {teams[i]}, 0 for {teams[j]}): ")
    return (i, j, 1 if user_input == '1' else 0)

def update_comparison_matrix(comp_matrix, i, j, result):
    """Update the comparison matrix based on user input"""
    if result == 1:
        comp_matrix[i, j] = 1
        comp_matrix[j, i] = 0
    else:
        comp_matrix[i, j] = 0
        comp_matrix[j, i] = 1
    return comp_matrix

def generate_data(n, dim=2):
    X = torch.rand(n, dim, dtype=torch.float64)
    return X

def init_and_fit_model(X, comp):
    model = PairwiseGP(
        datapoints=X,
        comparisons=comp,
        input_transform=Normalize(d=X.shape[-1]),
    )
    mll = PairwiseLaplaceMarginalLogLikelihood(model.likelihood, model)
    fit_gpytorch_mll(mll)
    return mll, model

def get_best_next_pair(comp_matrix, model, valid_pairs):
    """Find the pair (i, j) that maximizes the acquisition function"""
    best_value = -float('inf')
    best_pair = None
    acq_func = AnalyticExpectedUtilityOfBestOption(pref_model=model, previous_winner=None)
    for i, j in valid_pairs:
        with torch.no_grad():
            x = torch.tensor([[i], [j]], dtype=torch.float64).reshape(2, -1)
            value = acq_func(x.unsqueeze(0)).item()
            if value > best_value:
                best_value = value
                best_pair = (i, j)
    return best_pair

def filter_valid_pairs(comp_matrix):
    """Filter out pairs where at least one team has already lost"""
    valid_pairs = []
    for i in range(n_teams):
        if np.any(comp_matrix[i, :] == 0):
            continue
        for j in range(i + 1, n_teams):
            if np.isnan(comp_matrix[i, j]) and not np.any(comp_matrix[j, :] == 0):
                valid_pairs.append((i, j))
    return valid_pairs

# Ask the user for initial comparisons
initial_comparisons = []
initial_X_indices = [(0, 1), (2, 4), (3, 6)]
print("Please provide initial comparisons for the following teams:")
for i, j in initial_X_indices:
    team1, team2 = teams[i], teams[j]
    _, _, result = query_user_for_comparison(i, j)
    initial_comparisons.append((i, j, result))
    comp_matrix = update_comparison_matrix(comp_matrix, i, j, result)

comparisons = []
for comp in initial_comparisons:
    comparisons.append((comp[0], comp[1]) if comp[2] == 1 else (comp[1], comp[0]))
comparisons = torch.tensor(comparisons)

# Initialize the model with user-defined data
dim = 4
init_X = generate_data(n_teams, dim=dim)  # Generate enough data points for all teams
mll, model = init_and_fit_model(init_X, comparisons)

# Sequential Bayesian optimization loop
NUM_ITERATIONS = 10
best_observed_values = []

# Track the best observed value
current_best = float('-inf')

for iteration in range(NUM_ITERATIONS):
    # Find valid pairs to compare
    valid_pairs = filter_valid_pairs(comp_matrix)
    if not valid_pairs:
        print("No more valid pairs to query.")
        break

    # Get the best next pair (i, j)
    best_pair = get_best_next_pair(comp_matrix, model, valid_pairs)
    if best_pair is None:
        print("Failed to find a valid pair to query.")
        break

    i, j = best_pair
    _, _, result = query_user_for_comparison(i, j)
    comp_matrix = update_comparison_matrix(comp_matrix, i, j, result)
    comparisons = torch.cat([comparisons, torch.tensor([(i, j)] if result == 1 else [(j, i)])])
    
    # Update and refit the model
    mll, model = init_and_fit_model(init_X, comparisons)
    
    # Track the best observed value
    current_best = max(current_best, torch.max(model.posterior(init_X).mean).item())
    best_observed_values.append(current_best)

# Final model evaluation
# def eval_kt_cor(model, test_X):
#     pred_y = model.posterior(test_X).mean.squeeze().detach().numpy()
#     test_y = np.sum(test_X.numpy(), axis=1)
#     return kendalltau(pred_y, test_y).correlation

test_X = generate_data(1000, dim=dim)
# kt_correlation = eval_kt_cor(model, test_X)

# Plot the results
iters = list(range(1, NUM_ITERATIONS + 1))

plt.figure(figsize=(8, 6))
plt.plot(iters, best_observed_values, label="EUBO", linewidth=1.5, marker='o')
plt.xlabel("Number of queries")
plt.ylabel("Best observed value")
plt.title("Bayesian Optimization for Team Selection for a knockout tournament")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Teams:
# 1: Bangladesh
# 2: India
# 3: Pakistan
# 4: Nepal
# 5: Afghanistan
# 6: Sri Lanka
# 7: USA
# 8: South Africa
# 9: England
# 10: West Indies
# 11: Zimbabwe
# 12: Ireland
# 13: Netherlands
# 14: Canada
# 15: Australia
# 16: Kenya
# 17: Argentina
# Please provide initial comparisons for the following teams:
# ---------------------------------------------------------------------------
# BotorchTensorDimensionError               Traceback (most recent call last)
# Cell In[3], line 116
#     113     break
#     115 # Get the best next pair (i, j)
# --> 116 best_pair = get_best_next_pair(comp_matrix, model, valid_pairs)
#     117 if best_pair is None:
#     118     print("Failed to find a valid pair to query.")
#
# Cell In[3], line 64, in get_best_next_pair(comp_matrix, model, valid_pairs)
#      62 with torch.no_grad():
#      63     x = torch.tensor([[i], [j]], dtype=torch.float64).reshape(2, -1)
# ---> 64     value = acq_func(x.unsqueeze(0)).item()
#      65     if value > best_value:
#      66         best_value = value
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/utils/transforms.py:298, in t_batch_mode_transform.<locals>.decorator.<locals>.decorated(acqf, X, *args, **kwargs)
#     296 # add t-batch dim
#     297 X = X if X.dim() > 2 else X.unsqueeze(0)
# --> 298 output = method(acqf, X, *args, **kwargs)
#     299 if hasattr(acqf, "model") and is_ensemble(acqf.model):
#     300     # IDEA: this could be wrapped into SampleReducingMCAcquisitionFunction
#     301     output = (
#     302         output.mean(dim=-1) if not acqf._log else logmeanexp(output, dim=-1)
#     303     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/acquisition/preference.py:113, in AnalyticExpectedUtilityOfBestOption.forward(self, X)
#     110 if self.previous_winner is not None:
#     111     Y = torch.cat([Y, match_batch_shape(self.previous_winner, Y)], dim=-2)
# --> 113 pref_posterior = self.model.posterior(Y)
#     114 pref_mean = pref_posterior.mean.squeeze(-1)
#     115 pref_cov = pref_posterior.covariance_matrix
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/pairwise_gp.py:1098, in PairwiseGP.posterior(self, X, output_indices, observation_noise, posterior_transform)
#    1092 if output_indices is not None:
#    1093     raise RuntimeError(
#    1094         "output_indices is not None. PairwiseGP should not be a"
#    1095         "multi-output model."
#    1096     )
# -> 1098 post = self(X)
#    1099 posterior = GPyTorchPosterior(post)
#    1100 if posterior_transform is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gpytorch/module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/pairwise_gp.py:1011, in PairwiseGP.forward(self, datapoints)
#    1008 # Posterior mode
#    1009 else:
#    1010     transformed_dp = self.transform_inputs(self.datapoints)
# -> 1011     transformed_new_dp = self.transform_inputs(datapoints).to(transformed_dp)
#    1013     # self.utility might be None if exception was raised and _update
#    1014     # was failed to be called during hyperparameter optimization
#    1015     # procedures (e.g., fit_gpytorch_mll_scipy)
#    1016     if self.utility is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/model.py:217, in Model.transform_inputs(self, X, input_transform)
#     215     return input_transform(X)
#     216 try:
# --> 217     return self.input_transform(X)
#     218 except AttributeError:
#     219     return X
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/transforms/input.py:78, in InputTransform.forward(self, X)
#      76 elif self.transform_on_eval:
#      77     if fantasize.off() or self.transform_on_fantasize:
# ---> 78         return self.transform(X)
#      79 return X
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/transforms/input.py:396, in ReversibleInputTransform.transform(self, X)
#     387 def transform(self, X: Tensor) -> Tensor:
#     388     r"""Transform the inputs.
#     389
#     390     Args:
#    (...)
#     394         A `batch_shape x n x d`-dim tensor of transformed inputs.
#     395     """
# --> 396     return self._untransform(X) if self.reverse else self._transform(X)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/transforms/utils.py:122, in subset_transform.<locals>.f(self, X, **kwargs)
#     119 @wraps(transform)
#     120 def f(self, X: Tensor, **kwargs) -> Tensor:
#     121     if not hasattr(self, "indices") or self.indices is None:
# --> 122         return transform(self, X, **kwargs)
#     123     has_shape = hasattr(self, "batch_shape")
#     124     Y = expand_and_copy_tensor(X, self.batch_shape) if has_shape else X.clone()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/transforms/input.py:541, in AffineInputTransform._transform(self, X)
#     531 @subset_transform
#     532 def _transform(self, X: Tensor) -> Tensor:
#     533     r"""Apply affine transformation to input.
#     534
#     535     Args:
#    (...)
#     539         A `batch_shape x n x d`-dim tensor of transformed inputs.
#     540     """
# --> 541     self._check_shape(X)
#     542     if self.learn_coefficients and self.training:
#     543         self._update_coefficients(X)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botorch/models/transforms/input.py:587, in AffineInputTransform._check_shape(self, X)
#     583 """Checking input dimensions, included to increase code sharing
#     584 among the derived classes Normalize and InputStandardize.
#     585 """
#     586 if X.size(-1) != self.offset.size(-1):
# --> 587     raise BotorchTensorDimensionError(
#     588         f"Wrong input dimension. Received {X.size(-1)}, "
#     589         f"expected {self.offset.size(-1)}."
#     590     )
#     591 if X.ndim < 2:
#     592     raise BotorchTensorDimensionError(
#     593         f"`X` must have at least 2 dimensions, but has {X.ndim}."
#     594     )
#
# BotorchTensorDimensionError: Wrong input dimension. Received 1, expected 4.
